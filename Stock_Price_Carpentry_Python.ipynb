# %% [markdown]
# # Stock Price Carpentry.

# %% [markdown]
# In this notebook I test out my stock data preprocessing class and also attempt to connect to an api to pull data.

# %%
import pandas as pd

from source.preprocessing import preprocessor

# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import dates

# %%
data = pd.read_csv('AMZN.csv')

# %%
data['Adj Close'].plot()
# Out:
# <AxesSubplot:>

# %%
pp = preprocessor(data)

# %%
X_train, y_train, X_test, y_test = pp.trainTestSplit()
